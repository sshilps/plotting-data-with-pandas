# %%
import pandas as pd
import numpy as np

# %%
 data=pd.read_csv('Walmart_Store_sales.csv')

# %%
data.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
data.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
data['Store']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 6430    45
# 6431    45
# 6432    45
# 6433    45
# 6434    45
# Name: Store, Length: 6435, dtype: int64

# %%
data['Weekly_Sales'].plot()
# Out:
# <AxesSubplot:>

# %%
data['Weekly_Sales'].plot(legend=True)
# Out:
# <AxesSubplot:>

# %%
data.plot(title='Sample plot',figsize=(15,10))
# Out:
# <AxesSubplot:title={'center':'Sample plot'}>

# %%
data['Weekly_Sales'].plot(kind='box',title='Box plot')
# Out:
# <AxesSubplot:title={'center':'Box plot'}>

# %%
data['Weekly_Sales'].plot(kind='hist',title='Histogram')
# Out:
# <AxesSubplot:title={'center':'Histogram'}, ylabel='Frequency'>
